# %% [markdown]
# ## DICOM Reader
#
# Utility tool to read from DICOM MR images and do the following:
#
# - Save best slice image as NumPy file
# - Generate and save binary segmentation masks as NumPy files
# - Save Patient IDs with corresponding MUL values to CSV file
#
# 3000x speed improvement from previous version:
#
# - Old version:    5m 24.9s
# - This version:       0.1s

# %%
import pydicom
import numpy as np
import matplotlib.pyplot as plt
from skimage.draw import line
import os

# %%
# Replace paths
dicom_path = "../data/dicom_sagittal"
numpy_path = "../data"
dicomdir_path = os.path.join(dicom_path, "DICOMDIR")

# %%
dicomdir_dataset = pydicom.dcmread(dicomdir_path)

# Print out to inspect the DICOMDIR dataset contents
# print("---DATASET")
# print(dicomdir_dataset)

# %%
# Pre-process DICOM files to create an index mapping SOP Instance UIDs to file paths
def build_dicom_index_from_dicomdir(dicomdir_path):
    dicom_index = {}
    dicomdir_dataset = pydicom.dcmread(dicomdir_path)
    # print("---DATASET")
    # print(dicomdir_dataset)

    # Find the Directory Record Sequence
    directory_record_sequence = dicomdir_dataset.get((0x0004, 0x1220))
    # print("---SEQUENCE")
    # print(directory_record_sequence)

    count = 0
    # Iterate through the Directory Record Sequence
    for record in directory_record_sequence:
        if record.DirectoryRecordType == "IMAGE":
            # print("---RECORD IMAGE")
            # print(record)
            try:
                # Extract SOP Instance UID and file path
                sop_instance_uid = record.ReferencedSOPInstanceUIDInFile
                file_path = "/".join(record.ReferencedFileID)
                # print(count, sop_instance_uid, file_path)

                # Update the index
                dicom_index[sop_instance_uid] = file_path
                count += 1
            except Exception as e:
                print(e)
                continue

    return dicom_index


dicom_index = build_dicom_index_from_dicomdir(dicomdir_path)
# print(dicom_index)

# %%
print(f"Found {len(dicom_index)} images")

# Display first 10 items in the index
print({k: dicom_index[k] for k in list(dicom_index)[:10]})
# Out:
# Found 5412 images
# {'1.3.6.1.4.1.14519.5.2.1.7310.5101.312330389535335770866588983111': '6b7cd4da/bda8e51e/c2f1c6/cf7e7a7c', '1.3.6.1.4.1.14519.5.2.1.7310.5101.333802086270498941264908040381': 'd80ecb0a/f8b2719c/2b869432/56c56320', '1.3.6.1.4.1.14519.5.2.1.7310.5101.283621197730149193024583410294': '8bc59f8e/6335b3a8/f4cbdfa9/9feccc62', '1.3.6.1.4.1.14519.5.2.1.7310.5101.144213892326406999649971852351': '3f7c7412/9276366/f22dfe5d/7794c962', '1.3.6.1.4.1.14519.5.2.1.7310.5101.303809583121707351811548851702': 'f3334896/9f2fb7ad/73df3279/2d69538a', '1.3.6.1.4.1.14519.5.2.1.7310.5101.296321892660061826002851919706': '9ca182ca/a6d72e01/4ea97dad/d2b03479', '1.3.6.1.4.1.14519.5.2.1.7310.5101.986346696701218551045922551695': 'b9a0a908/6ba90cb4/4f8c95b4/a0e85b2c', '1.3.6.1.4.1.14519.5.2.1.7310.5101.480251647910816497812513236881': '5058574e/3acc6801/6638a89a/28a3cc78', '1.3.6.1.4.1.14519.5.2.1.7310.5101.126902383080474274276725971993': '6d577d8c/279a522e/e22c2200/d0cfd98f', '1.3.6.1.4.1.14519.5.2.1.7310.5101.276273066145738219919740370701': 'c732e7ce/be9e1f89/77ac17d7/5e9844a3'}

# %%
# Function to search for GSPS objects in the DICOMDIR file
def find_gsps_objects_in_dicomdir(dicomdir_path):
    gsps_objects = []

    dicomdir_dataset = pydicom.dcmread(dicomdir_path)
    # print(dicomdir_dataset)

    # Find the Directory Record Sequence
    directory_record_sequence = dicomdir_dataset.get((0x0004, 0x1220))

    # Iterate through the Directory Record Sequence
    for record in directory_record_sequence:
        # print("---- RECORD ----")
        # print(record)
        if record.DirectoryRecordType == "PRESENTATION":
            try:
                # Extract SOP Class UID
                sop_class_uid = record.get((0x0004, 0x1510)).value
                # print(sop_class_uid)
                if sop_class_uid == "1.2.840.10008.5.1.4.1.1.11.1":
                    # print(f"\nFound GSPS object")

                    gsps_file_path = os.path.join(dicom_path, *record.ReferencedFileID)
                    # print(gsps_file_path)
                    gsps_ds = pydicom.read_file(gsps_file_path)
                    # print("---- GSPS DS ----")
                    # print(gsps_ds)
                    gsps_objects.append(gsps_ds)

            except Exception as e:
                print(e)
                continue

    return gsps_objects


# Find GSPS objects in the DICOMDIR file
gsps_objects = find_gsps_objects_in_dicomdir(dicomdir_path)
print(gsps_objects)
# Out:
# [Dataset.file_meta -------------------------------
# (0002, 0000) File Meta Information Group Length  UL: 174
# (0002, 0001) File Meta Information Version       OB: b'\x00\x01'
# (0002, 0002) Media Storage SOP Class UID         UI: Grayscale Softcopy Presentation State Storage
# (0002, 0003) Media Storage SOP Instance UID      UI: 2.25.67411208332485720666945439369926249395
# (0002, 0010) Transfer Syntax UID                 UI: Implicit VR Little Endian
# (0002, 0012) Implementation Class UID            UI: 1.2.40.0.13.1.3
# (0002, 0013) Implementation Version Name         SH: 'dcm4che-5.30.0'
# -------------------------------------------------
# (0008, 0005) Specific Character Set              CS: 'ISO_IR 100'
# (0008, 0016) SOP Class UID                       UI: Grayscale Softcopy Presentation State Storage
# (0008, 0018) SOP Instance UID                    UI: 2.25.67411208332485720666945439369926249395
# (0008, 0020) Study Date                          DA: '20110305'
# (0008, 0023) Content Date                        DA: '20231102'
# (0008, 0030) Study Time                          TM: '113918.453000'
# (0008, 0033) Content Time                        TM: '195756.606'
# (0008, 0050) Accession Number                    SH: '2281530819099355'
# (0008, 0060) Modality                            CS: 'PR'
# (0008, 1010) Station Name                        SH: 'ahadjivasiliou.cs.ucl.ac.uk'
# (0008, 1030) Study Description                   LO: 'MR prostaat kanker detectie WDS_mc MCAPRODETW'
# (0008, 103e) Series Description                  LO: 'Weasis GSPS'
# (0008, 1115)  Referenced Series Sequence  1 item(s) ----
#    (0008, 1140)  Referenced Image Sequence  1 item(s) ----
#       (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.14519.5.2.1.7310.5101.207099700328596613096238203251
#       ---------
#    (0020, 000e) Series Instance UID                 UI: 1.3.6.1.4.1.14519.5.2.1.7310.5101.204187396203886006881765050486
#    ---------
# (0010, 0010) Patient's Name                      PN: 'ProstateX-0296'
# (0010, 0020) Patient ID                          LO: 'ProstateX-0296'
# (0010, 0030) Patient's Birth Date                DA: ''
# (0010, 0040) Patient's Sex                       CS: 'M'
# (0018, 1020) Software Versions                   LO: '4.2.0'
# (0020, 000d) Study Instance UID                  UI: 1.3.6.1.4.1.14519.5.2.1.7310.5101.664142249741974685840354452658
# (0020, 000e) Series Instance UID                 UI: 2.25.282041494724469587124080593623180182903
# (0020, 0010) Study ID                            SH: ''
# (0020, 0011) Series Number                       IS: '999'
# (0070, 0001)  Graphic Annotation Sequence  1 item(s) ----
#    (0070, 0002) Graphic Layer                       CS: 'MEASURE'
#    (0070, 0008)  Text Object Sequence  2 item(s) ----
#       (0070, 0003) Bounding Box Annotation Units       CS: 'PIXEL'
#       (0070, 0006) Unformatted Text Value              ST: 'Length : 19 mm'
#       (0070, 0010) Bounding Box Top Left Hand Corner   FL: [169.27110290527344, 220.61892700195312]
#       (0070, 0011) Bounding Box Bottom Right Hand Corn FL: [264.51409912109375, 238.617919921875]
#       ---------
#       (0070, 0003) Bounding Box Annotation Units       CS: 'PIXEL'
#       (0070, 0006) Unformatted Text Value              ST: 'Length : 16.7 mm'
#       (0070, 0010) Bounding Box Top Left Hand Corner   FL: [156.48338317871094, 216.46292114257812]
#       (0070, 0011) Bounding Box Bottom Right Hand Corn FL: [262.72637939453125, 234.4619140625]
#       ---------
#    (0070, 0009)  Graphic Object Sequence  2 item(s) ----
#       (0070, 0005) Graphic Annotation Units            CS: 'PIXEL'
#       (0070, 0020) Graphic Dimensions                  US: 2
#       (0070, 0021) Number of Graphic Points            US: 2
#       (0070, 0022) Graphic Data                        FL: [169.27110290527344, 209.55242919921875, 150.72889709472656, 237.6854248046875]
#       (0070, 0023) Graphic Type                        CS: 'POLYLINE'
#       (0070, 0024) Graphic Filled                      CS: 'N'
#       (0070, 0232)  Line Style Sequence  1 item(s) ----
#          (0070, 0251) Pattern On Color CIELab Value       US: [63658, 27358, 57178]
#          (0070, 0253) Line Thickness                      FL: 1.0
#          ---------
#       ---------
#       (0070, 0005) Graphic Annotation Units            CS: 'PIXEL'
#       (0070, 0020) Graphic Dimensions                  US: 2
#       (0070, 0021) Number of Graphic Points            US: 2
#       (0070, 0022) Graphic Data                        FL: [156.48338317871094, 206.35549926757812, 142.41688537597656, 232.57032775878906]
#       (0070, 0023) Graphic Type                        CS: 'POLYLINE'
#       (0070, 0024) Graphic Filled                      CS: 'N'
#       (0070, 0232)  Line Style Sequence  1 item(s) ----
#          (0070, 0251) Pattern On Color CIELab Value       US: [63658, 27358, 57178]
#          (0070, 0253) Line Thickness                      FL: 1.0
#          ---------
#       ---------
#    ---------
# (0070, 0060)  Graphic Layer Sequence  1 item(s) ----
#    (0070, 0002) Graphic Layer                       CS: 'MEASURE'
#    (0070, 0062) Graphic Layer Order                 IS: '0'
#    (0070, 0068) Graphic Layer Description           LO: 'Measurements'
#    (0070, 0401) Graphic Layer Recommended Display C US: [63658, 27358, 57178]
#    ---------
# (0070, 0080) Content Label                       CS: 'GSPS'
# (0070, 0081) Content Description                 LO: 'Description'
# (0070, 0082) Presentation Creation Date          DA: '20231102'
# (0070, 0083) Presentation Creation Time          TM: '195756.606'
# (0070, 0084) Content Creator's Name              PN: 'adamoshadjivasiliou'
# (7107, 0070) Private Creator                     LO: 'weasis/model/xml/2.5'
# (7107, 7001) Private tag data                    UN: Array of 610 elements, Dataset.file_meta -------------------------------
# (0002, 0000) File Meta Information Group Length  UL: 174
# (0002, 0001) File Meta Information Version       OB: b'\x00\x01'
# (0002, 0002) Media Storage SOP Class UID         UI: Grayscale Softcopy Presentation State Storage
# (0002, 0003) Media Storage SOP Instance UID      UI: 2.25.160229146780769959803279504287251450908
# (0002, 0010) Transfer Syntax UID                 UI: Implicit VR Little Endian
# (0002, 0012) Implementation Class UID            UI: 1.2.40.0.13.1.3
# (0002, 0013) Implementation Version Name         SH: 'dcm4che-5.30.0'
# -------------------------------------------------
# (0008, 0005) Specific Character Set              CS: 'ISO_IR 100'
# (0008, 0016) SOP Class UID                       UI: Grayscale Softcopy Presentation State Storage
# (0008, 0018) SOP Instance UID                    UI: 2.25.160229146780769959803279504287251450908
# (0008, 0020) Study Date                          DA: '20110308'
# (0008, 0023) Content Date                        DA: '20231102'
# (0008, 0030) Study Time                          TM: '151321.359000'
# (0008, 0033) Content Time                        TM: '195757.181'
# (0008, 0050) Accession Number                    SH: '1390028602507457'
# (0008, 0060) Modality                            CS: 'PR'
# (0008, 1010) Station Name                        SH: 'ahadjivasiliou.cs.ucl.ac.uk'
# (0008, 1030) Study Description                   LO: 'MR prostaat kanker detectie WDS_mc MCAPRODETW'
# (0008, 103e) Series Description                  LO: 'Weasis GSPS'
# (0008, 1115)  Referenced Series Sequence  1 item(s) ----
#    (0008, 1140)  Referenced Image Sequence  1 item(s) ----
#       (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.14519.5.2.1.7310.5101.270944172932129682002353040091
#       ---------
#    (0020, 000e) Series Instance UID                 UI: 1.3.6.1.4.1.14519.5.2.1.7310.5101.130579816183264896455215068567
#    ---------
# (0010, 0010) Patient's Name                      PN: 'ProstateX-0299'
# (0010, 0020) Patient ID                          LO: 'ProstateX-0299'
# (0010, 0030) Patient's Birth Date                DA: ''
# (0010, 0040) Patient's Sex                       CS: 'M'
# (0018, 1020) Software Versions                   LO: '4.2.0'
# (0020, 000d) Study Instance UID                  UI: 1.3.6.1.4.1.14519.5.2.1.7310.5101.178611086588027479377909030592
# (0020, 000e) Series Instance UID                 UI: 2.25.145380496422262421479199285204654500803
# (0020, 0010) Study ID                            SH: ''
# (0020, 0011) Series Number                       IS: '999'
# (0070, 0001)  Graphic Annotation Sequence  1 item(s) ----
#    (0070, 0002) Graphic Layer                       CS: 'MEASURE'
#    (0070, 0008)  Text Object Sequence  2 item(s) ----
#       (0070, 0003) Bounding Box Annotation Units       CS: 'PIXEL'
#       (0070, 0006) Unformatted Text Value              ST: 'Length : 14.5 mm'
#       (0070, 0010) Bounding Box Top Left Hand Corner   FL: [138.58056640625, 200.47825622558594]
#       (0070, 0011) Bounding Box Bottom Right Hand Corn FL: [244.8235626220703, 218.47726440429688]
#       ---------
#       (0070, 0003) Bounding Box Annotation Units       CS: 'PIXEL'
#       (0070, 0006) Unformatted Text Value              ST: 'Length : 12.4 mm'
#       (0070, 0010) Bounding Box Top Left Hand Corner   FL: [130.90792846679688, 199.8388671875]
#       (0070, 0011) Bounding Box Bottom Right Hand Corn FL: [237.1509246826172, 217.83787536621094]
#       ---------
#    (0070, 0009)  Graphic Object Sequence  2 item(s) ----
#       (0070, 0005) Graphic Annotation Units            CS: 'PIXEL'
#       (0070, 0020) Graphic Dimensions                  US: 2
#       (0070, 0021) Number of Graphic Points            US: 2
#       (0070, 0022) Graphic Data                        FL: [138.58056640625, 191.01022338867188, 132.18670654296875, 215.9462890625]
#       (0070, 0023) Graphic Type                        CS: 'POLYLINE'
#       (0070, 0024) Graphic Filled                      CS: 'N'
#       (0070, 0232)  Line Style Sequence  1 item(s) ----
#          (0070, 0251) Pattern On Color CIELab Value       US: [63658, 27358, 57178]
#          (0070, 0253) Line Thickness                      FL: 1.0
#          ---------
#       ---------
#       (0070, 0005) Graphic Annotation Units            CS: 'PIXEL'
#       (0070, 0020) Graphic Dimensions                  US: 2
#       (0070, 0021) Number of Graphic Points            US: 2
#       (0070, 0022) Graphic Data                        FL: [130.90792846679688, 192.28900146484375, 124.51406860351562, 213.3887481689453]
#       (0070, 0023) Graphic Type                        CS: 'POLYLINE'
#       (0070, 0024) Graphic Filled                      CS: 'N'
#       (0070, 0232)  Line Style Sequence  1 item(s) ----
#          (0070, 0251) Pattern On Color CIELab Value       US: [63658, 27358, 57178]
#          (0070, 0253) Line Thickness                      FL: 1.0
#          ---------
#       ---------
#    ---------
# (0070, 0060)  Graphic Layer Sequence  1 item(s) ----
#    (0070, 0002) Graphic Layer                       CS: 'MEASURE'
#    (0070, 0062) Graphic Layer Order                 IS: '0'
#    (0070, 0068) Graphic Layer Description           LO: 'Measurements'
#    (0070, 0401) Graphic Layer Recommended Display C US: [63658, 27358, 57178]
#    ---------
# (0070, 0080) Content Label                       CS: 'GSPS'
# (0070, 0081) Content Description                 LO: 'Description'
# (0070, 0082) Presentation Creation Date          DA: '20231102'
# (0070, 0083) Presentation Creation Time          TM: '195757.181'
# (0070, 0084) Content Creator's Name              PN: 'adamoshadjivasiliou'
# (7107, 0070) Private Creator                     LO: 'weasis/model/xml/2.5'
# (7107, 7001) Private tag data                    UN: Array of 606 elements, Dataset.file_meta -------------------------------
# (0002, 0000) File Meta Information Group Length  UL: 174
# (0002, 0001) File Meta Information Version       OB: b'\x00\x01'
# (0002, 0002) Media Storage SOP Class UID         UI: Grayscale Softcopy Presentation State Storage
# (0002, 0003) Media Storage SOP Instance UID      UI: 2.25.86051070498696185267176199245171827820
# (0002, 0010) Transfer Syntax UID                 UI: Implicit VR Little Endian
# (0002, 0012) Implementation Class UID            UI: 1.2.40.0.13.1.3
# (0002, 0013) Implementation Version Name         SH: 'dcm4che-5.30.0'
# -------------------------------------------------
# (0008, 0005) Specific Character Set              CS: 'ISO_IR 100'
# (0008, 0016) SOP Class UID                       UI: Grayscale Softcopy Presentation State Storage
# (0008, 0018) SOP Instance UID                    UI: 2.25.86051070498696185267176199245171827820
# (0008, 0020) Study Date                          DA: '20110303'
# (0008, 0023) Content Date                        DA: '20231102'
# (0008, 0030) Study Time                          TM: '084234.187000'
# (0008, 0033) Content Time                        TM: '195757.468'
# (0008, 0050) Accession Number                    SH: '1529742637797755'
# (0008, 0060) Modality                            CS: 'PR'
# (0008, 1010) Station Name                        SH: 'ahadjivasiliou.cs.ucl.ac.uk'
# (0008, 1030) Study Description                   LO: 'MR prostaat kanker detectie WDS_mc MCAPRODETW'
# (0008, 103e) Series Description                  LO: 'Weasis GSPS'
# (0008, 1115)  Referenced Series Sequence  1 item(s) ----
#    (0008, 1140)  Referenced Image Sequence  1 item(s) ----
#       (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.14519.5.2.1.7310.5101.228111773347525268000423213249
#       ---------
#    (0020, 000e) Series Instance UID                 UI: 1.3.6.1.4.1.14519.5.2.1.7310.5101.139175634699408141014797174400
#    ---------
# (0010, 0010) Patient's Name                      PN: 'ProstateX-0293'
# (0010, 0020) Patient ID                          LO: 'ProstateX-0293'
# (0010, 0030) Patient's Birth Date                DA: ''
# (0010, 0040) Patient's Sex                       CS: 'M'
# (0018, 1020) Software Versions                   LO: '4.2.0'
# (0020, 000d) Study Instance UID                  UI: 1.3.6.1.4.1.14519.5.2.1.7310.5101.112931091237257216369383689487
# (0020, 000e) Series Instance UID                 UI: 2.25.116612659179044242000091308440622402297
# (0020, 0010) Study ID                            SH: ''
# (0020, 0011) Series Number                       IS: '999'
# (0070, 0001)  Graphic Annotation Sequence  1 item(s) ----
#    (0070, 0002) Graphic Layer                       CS: 'MEASURE'
#    (0070, 0008)  Text Object Sequence  2 item(s) ----
#       (0070, 0003) Bounding Box Annotation Units       CS: 'PIXEL'
#       (0070, 0006) Unformatted Text Value              ST: 'Length : 11.2 mm'
#       (0070, 0010) Bounding Box Top Left Hand Corner   FL: [157.76214599609375, 213.58567810058594]
#       (0070, 0011) Bounding Box Bottom Right Hand Corn FL: [264.0051574707031, 231.5846710205078]
#       ---------
#       (0070, 0003) Bounding Box Annotation Units       CS: 'PIXEL'
#       (0070, 0006) Unformatted Text Value              ST: 'Length : 12.8 mm'
#       (0070, 0010) Bounding Box Top Left Hand Corner   FL: [146.892578125, 209.74935913085938]
#       (0070, 0011) Bounding Box Bottom Right Hand Corn FL: [253.1355743408203, 227.7483673095703]
#       ---------
#    (0070, 0009)  Graphic Object Sequence  2 item(s) ----
#       (0070, 0005) Graphic Annotation Units            CS: 'PIXEL'
#       (0070, 0020) Graphic Dimensions                  US: 2
#       (0070, 0021) Number of Graphic Points            US: 2
#       (0070, 0022) Graphic Data                        FL: [157.76214599609375, 208.27365112304688, 146.892578125, 224.897705078125]
#       (0070, 0023) Graphic Type                        CS: 'POLYLINE'
#       (0070, 0024) Graphic Filled                      CS: 'N'
#       (0070, 0232)  Line Style Sequence  1 item(s) ----
#          (0070, 0251) Pattern On Color CIELab Value       US: [63658, 27358, 57178]
#          (0070, 0253) Line Thickness                      FL: 1.0
#          ---------
#       ---------
#       (0070, 0005) Graphic Annotation Units            CS: 'PIXEL'
#       (0070, 0020) Graphic Dimensions                  US: 2
#       (0070, 0021) Number of Graphic Points            US: 2
#       (0070, 0022) Graphic Data                        FL: [146.892578125, 203.1585693359375, 134.74424743652344, 222.34014892578125]
#       (0070, 0023) Graphic Type                        CS: 'POLYLINE'
#       (0070, 0024) Graphic Filled                      CS: 'N'
#       (0070, 0232)  Line Style Sequence  1 item(s) ----
#          (0070, 0251) Pattern On Color CIELab Value       US: [63658, 27358, 57178]
#          (0070, 0253) Line Thickness                      FL: 1.0
#          ---------
#       ---------
#    ---------
# (0070, 0060)  Graphic Layer Sequence  1 item(s) ----
#    (0070, 0002) Graphic Layer                       CS: 'MEASURE'
#    (0070, 0062) Graphic Layer Order                 IS: '0'
#    (0070, 0068) Graphic Layer Description           LO: 'Measurements'
#    (0070, 0401) Graphic Layer Recommended Display C US: [63658, 27358, 57178]
#    ---------
# (0070, 0080) Content Label                       CS: 'GSPS'
# (0070, 0081) Content Description                 LO: 'Description'
# (0070, 0082) Presentation Creation Date          DA: '20231102'
# (0070, 0083) Presentation Creation Time          TM: '195757.468'
# (0070, 0084) Content Creator's Name              PN: 'adamoshadjivasiliou'
# (7107, 0070) Private Creator                     LO: 'weasis/model/xml/2.5'
# (7107, 7001) Private tag data                    UN: Array of 606 elements, Dataset.file_meta -------------------------------
# (0002, 0000) File Meta Information Group Length  UL: 174
# (0002, 0001) File Meta Information Version       OB: b'\x00\x01'
# (0002, 0002) Media Storage SOP Class UID         UI: Grayscale Softcopy Presentation State Storage
# (0002, 0003) Media Storage SOP Instance UID      UI: 2.25.93938833805231290678301299962101217534
# (0002, 0010) Transfer Syntax UID                 UI: Implicit VR Little Endian
# (0002, 0012) Implementation Class UID            UI: 1.2.40.0.13.1.3
# (0002, 0013) Implementation Version Name         SH: 'dcm4che-5.30.0'
# -------------------------------------------------
# (0008, 0005) Specific Character Set              CS: 'ISO_IR 100'
# (0008, 0016) SOP Class UID                       UI: Grayscale Softcopy Presentation State Storage
# (0008, 0018) SOP Instance UID                    UI: 2.25.93938833805231290678301299962101217534
# (0008, 0020) Study Date                          DA: '20110227'
# (0008, 0023) Content Date                        DA: '20231102'
# (0008, 0030) Study Time                          TM: '143525.531000'
# (0008, 0033) Content Time                        TM: '195757.643'
# (0008, 0050) Accession Number                    SH: '2826954109080476'
# (0008, 0060) Modality                            CS: 'PR'
# (0008, 1010) Station Name                        SH: 'ahadjivasiliou.cs.ucl.ac.uk'
# (0008, 1030) Study Description                   LO: 'MR prostaat kanker detectie WDS_mc MCAPRODETW'
# (0008, 103e) Series Description                  LO: 'Weasis GSPS'
# (0008, 1115)  Referenced Series Sequence  1 item(s) ----
#    (0008, 1140)  Referenced Image Sequence  1 item(s) ----
#       (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.14519.5.2.1.7310.5101.140741776358105176341511390154
#       ---------
#    (0020, 000e) Series Instance UID                 UI: 1.3.6.1.4.1.14519.5.2.1.7310.5101.258759220063492511320873097858
#    ---------
# (0010, 0010) Patient's Name                      PN: 'ProstateX-0286'
# (0010, 0020) Patient ID                          LO: 'ProstateX-0286'
# (0010, 0030) Patient's Birth Date                DA: ''
# (0010, 0040) Patient's Sex                       CS: 'M'
# (0018, 1020) Software Versions                   LO: '4.2.0'
# (0020, 000d) Study Instance UID                  UI: 1.3.6.1.4.1.14519.5.2.1.7310.5101.953893046658414902612620647433
# (0020, 000e) Series Instance UID                 UI: 2.25.183917273866361979671486240219757878045
# (0020, 0010) Study ID                            SH: ''
# (0020, 0011) Series Number                       IS: '999'
# (0070, 0001)  Graphic Annotation Sequence  1 item(s) ----
#    (0070, 0002) Graphic Layer                       CS: 'MEASURE'
#    (0070, 0008)  Text Object Sequence  2 item(s) ----
#       (0070, 0003) Bounding Box Annotation Units       CS: 'PIXEL'
#       (0070, 0006) Unformatted Text Value              ST: 'Length : 14.8 mm'
#       (0070, 0010) Bounding Box Top Left Hand Corner   FL: [167.99232482910156, 218.06138610839844]
#       (0070, 0011) Bounding Box Bottom Right Hand Corn FL: [274.2353210449219, 236.0603790283203]
#       ---------
#       (0070, 0003) Bounding Box Annotation Units       CS: 'PIXEL'
#       (0070, 0006) Unformatted Text Value              ST: 'Length : 12.7 mm'
#       (0070, 0010) Bounding Box Top Left Hand Corner   FL: [157.76214599609375, 218.38107299804688]
#       (0070, 0011) Bounding Box Bottom Right Hand Corn FL: [264.0051574707031, 236.3800811767578]
#       ---------
#    (0070, 0009)  Graphic Object Sequence  2 item(s) ----
#       (0070, 0005) Graphic Annotation Units            CS: 'PIXEL'
#       (0070, 0020) Graphic Dimensions                  US: 2
#       (0070, 0021) Number of Graphic Points            US: 2
#       (0070, 0022) Graphic Data                        FL: [167.99232482910156, 209.55242919921875, 155.20460510253906, 232.57032775878906]
#       (0070, 0023) Graphic Type                        CS: 'POLYLINE'
#       (0070, 0024) Graphic Filled                      CS: 'N'
#       (0070, 0232)  Line Style Sequence  1 item(s) ----
#          (0070, 0251) Pattern On Color CIELab Value       US: [63658, 27358, 57178]
#          (0070, 0253) Line Thickness                      FL: 1.0
#          ---------
#       ---------
#       (0070, 0005) Graphic Annotation Units            CS: 'PIXEL'
#       (0070, 0020) Graphic Dimensions                  US: 2
#       (0070, 0021) Number of Graphic Points            US: 2
#       (0070, 0022) Graphic Data                        FL: [157.76214599609375, 211.4705810546875, 146.892578125, 231.29156494140625]
#       (0070, 0023) Graphic Type                        CS: 'POLYLINE'
#       (0070, 0024) Graphic Filled                      CS: 'N'
#       (0070, 0232)  Line Style Sequence  1 item(s) ----
#          (0070, 0251) Pattern On Color CIELab Value       US: [63658, 27358, 57178]
#          (0070, 0253) Line Thickness                      FL: 1.0
#          ---------
#       ---------
#    ---------
# (0070, 0060)  Graphic Layer Sequence  1 item(s) ----
#    (0070, 0002) Graphic Layer                       CS: 'MEASURE'
#    (0070, 0062) Graphic Layer Order                 IS: '0'
#    (0070, 0068) Graphic Layer Description           LO: 'Measurements'
#    (0070, 0401) Graphic Layer Recommended Display C US: [63658, 27358, 57178]
#    ---------
# (0070, 0080) Content Label                       CS: 'GSPS'
# (0070, 0081) Content Description                 LO: 'Description'
# (0070, 0082) Presentation Creation Date          DA: '20231102'
# (0070, 0083) Presentation Creation Time          TM: '195757.643'
# (0070, 0084) Content Creator's Name              PN: 'adamoshadjivasiliou'
# (7107, 0070) Private Creator                     LO: 'weasis/model/xml/2.5'
# (7107, 7001) Private tag data                    UN: Array of 612 elements, Dataset.file_meta -------------------------------
# (0002, 0000) File Meta Information Group Length  UL: 174
# (0002, 0001) File Meta Information Version       OB: b'\x00\x01'
# (0002, 0002) Media Storage SOP Class UID         UI: Grayscale Softcopy Presentation State Storage
# (0002, 0003) Media Storage SOP Instance UID      UI: 2.25.129029559960393983562463391784738762921
# (0002, 0010) Transfer Syntax UID                 UI: Implicit VR Little Endian
# (0002, 0012) Implementation Class UID            UI: 1.2.40.0.13.1.3
# (0002, 0013) Implementation Version Name         SH: 'dcm4che-5.30.0'
# -------------------------------------------------
# (0008, 0005) Specific Character Set              CS: 'ISO_IR 100'
# (0008, 0016) SOP Class UID                       UI: Grayscale Softcopy Presentation State Storage
# (0008, 0018) SOP Instance UID                    UI: 2.25.129029559960393983562463391784738762921
# (0008, 0020) Study Date                          DA: '20110304'
# (0008, 0023) Content Date                        DA: '20231102'
# (0008, 0030) Study Time                          TM: '110724.562000'
# (0008, 0033) Content Time                        TM: '195757.776'
# (0008, 0050) Accession Number                    SH: '3389347690941761'
# (0008, 0060) Modality                            CS: 'PR'
# (0008, 1010) Station Name                        SH: 'ahadjivasiliou.cs.ucl.ac.uk'
# (0008, 1030) Study Description                   LO: 'MR prostaat kanker detectie WDS_mc MCAPRODETW'
# (0008, 103e) Series Description                  LO: 'Weasis GSPS'
# (0008, 1115)  Referenced Series Sequence  1 item(s) ----
#    (0008, 1140)  Referenced Image Sequence  1 item(s) ----
#       (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.14519.5.2.1.7310.5101.189734871718400425962734105105
#       ---------
#    (0020, 000e) Series Instance UID                 UI: 1.3.6.1.4.1.14519.5.2.1.7310.5101.569990876125008076220854337515
#    ---------
# (0010, 0010) Patient's Name                      PN: 'ProstateX-0294'
# (0010, 0020) Patient ID                          LO: 'ProstateX-0294'
# (0010, 0030) Patient's Birth Date                DA: ''
# (0010, 0040) Patient's Sex                       CS: 'M'
# (0018, 1020) Software Versions                   LO: '4.2.0'
# (0020, 000d) Study Instance UID                  UI: 1.3.6.1.4.1.14519.5.2.1.7310.5101.307625237561151938788302143251
# (0020, 000e) Series Instance UID                 UI: 2.25.98972823124863773045536516807134043387
# (0020, 0010) Study ID                            SH: ''
# (0020, 0011) Series Number                       IS: '999'
# (0070, 0001)  Graphic Annotation Sequence  1 item(s) ----
#    (0070, 0002) Graphic Layer                       CS: 'MEASURE'
#    (0070, 0008)  Text Object Sequence  2 item(s) ----
#       (0070, 0003) Bounding Box Annotation Units       CS: 'PIXEL'
#       (0070, 0006) Unformatted Text Value              ST: 'Length : 21.9 mm'
#       (0070, 0010) Bounding Box Top Left Hand Corner   FL: [177.58311462402344, 217.4219970703125]
#       (0070, 0011) Bounding Box Bottom Right Hand Corn FL: [283.82611083984375, 235.42098999023438]
#       ---------
#       (0070, 0003) Bounding Box Annotation Units       CS: 'PIXEL'
#       (0070, 0006) Unformatted Text Value              ST: 'Length : 19 mm'
#       (0070, 0010) Bounding Box Top Left Hand Corner   FL: [163.51661682128906, 215.5038299560547]
#       (0070, 0011) Bounding Box Bottom Right Hand Corn FL: [258.7596130371094, 233.50283813476562]
#       ---------
#    (0070, 0009)  Graphic Object Sequence  2 item(s) ----
#       (0070, 0005) Graphic Annotation Units            CS: 'PIXEL'
#       (0070, 0020) Graphic Dimensions                  US: 2
#       (0070, 0021) Number of Graphic Points            US: 2
#       (0070, 0022) Graphic Data                        FL: [177.58311462402344, 202.51918029785156, 162.23785400390625, 238.32481384277344]
#       (0070, 0023) Graphic Type                        CS: 'POLYLINE'
#       (0070, 0024) Graphic Filled                      CS: 'N'
#       (0070, 0232)  Line Style Sequence  1 item(s) ----
#          (0070, 0251) Pattern On Color CIELab Value       US: [63658, 27358, 57178]
#          (0070, 0253) Line Thickness                      FL: 1.0
#          ---------
#       ---------
#       (0070, 0005) Graphic Annotation Units            CS: 'PIXEL'
#       (0070, 0020) Graphic Dimensions                  US: 2
#       (0070, 0021) Number of Graphic Points            US: 2
#       (0070, 0022) Graphic Data                        FL: [163.51661682128906, 203.1585693359375, 149.45013427734375, 233.84910583496094]
#       (0070, 0023) Graphic Type                        CS: 'POLYLINE'
#       (0070, 0024) Graphic Filled                      CS: 'N'
#       (0070, 0232)  Line Style Sequence  1 item(s) ----
#          (0070, 0251) Pattern On Color CIELab Value       US: [63658, 27358, 57178]
#          (0070, 0253) Line Thickness                      FL: 1.0
#          ---------
#       ---------
#    ---------
# (0070, 0060)  Graphic Layer Sequence  1 item(s) ----
#    (0070, 0002) Graphic Layer                       CS: 'MEASURE'
#    (0070, 0062) Graphic Layer Order                 IS: '0'
#    (0070, 0068) Graphic Layer Description           LO: 'Measurements'
#    (0070, 0401) Graphic Layer Recommended Display C US: [63658, 27358, 57178]
#    ---------
# (0070, 0080) Content Label                       CS: 'GSPS'
# (0070, 0081) Content Description                 LO: 'Description'
# (0070, 0082) Presentation Creation Date          DA: '20231102'
# (0070, 0083) Presentation Creation Time          TM: '195757.776'
# (0070, 0084) Content Creator's Name              PN: 'adamoshadjivasiliou'
# (7107, 0070) Private Creator                     LO: 'weasis/model/xml/2.5'
# (7107, 7001) Private tag data                    UN: Array of 606 elements, Dataset.file_meta -------------------------------
# (0002, 0000) File Meta Information Group Length  UL: 172
# (0002, 0001) File Meta Information Version       OB: b'\x00\x01'
# (0002, 0002) Media Storage SOP Class UID         UI: Grayscale Softcopy Presentation State Storage
# (0002, 0003) Media Storage SOP Instance UID      UI: 2.25.1445863163993859895346451257696333094
# (0002, 0010) Transfer Syntax UID                 UI: Implicit VR Little Endian
# (0002, 0012) Implementation Class UID            UI: 1.2.40.0.13.1.3
# (0002, 0013) Implementation Version Name         SH: 'dcm4che-5.30.0'
# -------------------------------------------------
# (0008, 0005) Specific Character Set              CS: 'ISO_IR 100'
# (0008, 0016) SOP Class UID                       UI: Grayscale Softcopy Presentation State Storage
# (0008, 0018) SOP Instance UID                    UI: 2.25.1445863163993859895346451257696333094
# (0008, 0020) Study Date                          DA: '20110301'
# (0008, 0023) Content Date                        DA: '20231102'
# (0008, 0030) Study Time                          TM: '140045.281000'
# (0008, 0033) Content Time                        TM: '195758.091'
# (0008, 0050) Accession Number                    SH: '3011444061725064'
# (0008, 0060) Modality                            CS: 'PR'
# (0008, 1010) Station Name                        SH: 'ahadjivasiliou.cs.ucl.ac.uk'
# (0008, 1030) Study Description                   LO: 'MC prostaat kliniek detectie-mc MCPROSKL30'
# (0008, 103e) Series Description                  LO: 'Weasis GSPS'
# (0008, 1115)  Referenced Series Sequence  1 item(s) ----
#    (0008, 1140)  Referenced Image Sequence  1 item(s) ----
#       (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.14519.5.2.1.7310.5101.217246643289067839554381811218
#       ---------
#    (0020, 000e) Series Instance UID                 UI: 1.3.6.1.4.1.14519.5.2.1.7310.5101.162635886376111902729637744565
#    ---------
# (0010, 0010) Patient's Name                      PN: 'ProstateX-0290'
# (0010, 0020) Patient ID                          LO: 'ProstateX-0290'
# (0010, 0030) Patient's Birth Date                DA: ''
# (0010, 0040) Patient's Sex                       CS: 'M'
# (0018, 1020) Software Versions                   LO: '4.2.0'
# (0020, 000d) Study Instance UID                  UI: 1.3.6.1.4.1.14519.5.2.1.7310.5101.162345827061760513823921554312
# (0020, 000e) Series Instance UID                 UI: 2.25.279829806430994612341138326204019377908
# (0020, 0010) Study ID                            SH: ''
# (0020, 0011) Series Number                       IS: '999'
# (0070, 0001)  Graphic Annotation Sequence  1 item(s) ----
#    (0070, 0002) Graphic Layer                       CS: 'MEASURE'
#    (0070, 0008)  Text Object Sequence  2 item(s) ----
#       (0070, 0003) Bounding Box Annotation Units       CS: 'PIXEL'
#       (0070, 0006) Unformatted Text Value              ST: 'Length : 20.8 mm'
#       (0070, 0010) Bounding Box Top Left Hand Corner   FL: [161.5984649658203, 212.62660217285156]
#       (0070, 0011) Bounding Box Bottom Right Hand Corn FL: [267.8414611816406, 230.62559509277344]
#       ---------
#       (0070, 0003) Bounding Box Annotation Units       CS: 'PIXEL'
#       (0070, 0006) Unformatted Text Value              ST: 'Length : 17.9 mm'
#       (0070, 0010) Bounding Box Top Left Hand Corner   FL: [152.64706420898438, 213.58567810058594]
#       (0070, 0011) Bounding Box Bottom Right Hand Corn FL: [258.8900451660156, 231.5846710205078]
#       ---------
#    (0070, 0009)  Graphic Object Sequence  2 item(s) ----
#       (0070, 0005) Graphic Annotation Units            CS: 'PIXEL'
#       (0070, 0020) Graphic Dimensions                  US: 2
#       (0070, 0021) Number of Graphic Points            US: 2
#       (0070, 0022) Graphic Data                        FL: [161.5984649658203, 198.682861328125, 146.892578125, 232.57032775878906]
#       (0070, 0023) Graphic Type                        CS: 'POLYLINE'
#       (0070, 0024) Graphic Filled                      CS: 'N'
#       (0070, 0232)  Line Style Sequence  1 item(s) ----
#          (0070, 0251) Pattern On Color CIELab Value       US: [63658, 27358, 57178]
#          (0070, 0253) Line Thickness                      FL: 1.0
#          ---------
#       ---------
#       (0070, 0005) Graphic Annotation Units            CS: 'PIXEL'
#       (0070, 0020) Graphic Dimensions                  US: 2
#       (0070, 0021) Number of Graphic Points            US: 2
#       (0070, 0022) Graphic Data                        FL: [152.64706420898438, 202.51918029785156, 137.94117736816406, 230.6521759033203]
#       (0070, 0023) Graphic Type                        CS: 'POLYLINE'
#       (0070, 0024) Graphic Filled                      CS: 'N'
#       (0070, 0232)  Line Style Sequence  1 item(s) ----
#          (0070, 0251) Pattern On Color CIELab Value       US: [63658, 27358, 57178]
#          (0070, 0253) Line Thickness                      FL: 1.0
#          ---------
#       ---------
#    ---------
# (0070, 0060)  Graphic Layer Sequence  1 item(s) ----
#    (0070, 0002) Graphic Layer                       CS: 'MEASURE'
#    (0070, 0062) Graphic Layer Order                 IS: '0'
#    (0070, 0068) Graphic Layer Description           LO: 'Measurements'
#    (0070, 0401) Graphic Layer Recommended Display C US: [63658, 27358, 57178]
#    ---------
# (0070, 0080) Content Label                       CS: 'GSPS'
# (0070, 0081) Content Description                 LO: 'Description'
# (0070, 0082) Presentation Creation Date          DA: '20231102'
# (0070, 0083) Presentation Creation Time          TM: '195758.091'
# (0070, 0084) Content Creator's Name              PN: 'adamoshadjivasiliou'
# (7107, 0070) Private Creator                     LO: 'weasis/model/xml/2.5'
# (7107, 7001) Private tag data                    UN: Array of 610 elements, Dataset.file_meta -------------------------------
# (0002, 0000) File Meta Information Group Length  UL: 172
# (0002, 0001) File Meta Information Version       OB: b'\x00\x01'
# (0002, 0002) Media Storage SOP Class UID         UI: Grayscale Softcopy Presentation State Storage
# (0002, 0003) Media Storage SOP Instance UID      UI: 2.25.1527659686998842554111665059392643457
# (0002, 0010) Transfer Syntax UID                 UI: Implicit VR Little Endian
# (0002, 0012) Implementation Class UID            UI: 1.2.40.0.13.1.3
# (0002, 0013) Implementation Version Name         SH: 'dcm4che-5.30.0'
# -------------------------------------------------
# (0008, 0005) Specific Character Set              CS: 'ISO_IR 100'
# (0008, 0016) SOP Class UID                       UI: Grayscale Softcopy Presentation State Storage
# (0008, 0018) SOP Instance UID                    UI: 2.25.1527659686998842554111665059392643457
# (0008, 0020) Study Date                          DA: '20110308'
# (0008, 0023) Content Date                        DA: '20231102'
# (0008, 0030) Study Time                          TM: '100829.328000'
# (0008, 0033) Content Time                        TM: '195758.185'
# (0008, 0050) Accession Number                    SH: '9747920254740773'
# (0008, 0060) Modality                            CS: 'PR'
# (0008, 1010) Station Name                        SH: 'ahadjivasiliou.cs.ucl.ac.uk'
# (0008, 1030) Study Description                   LO: 'MC prostaat kliniek detectie-mc MCPROSKL30'
# (0008, 103e) Series Description                  LO: 'Weasis GSPS'
# (0008, 1115)  Referenced Series Sequence  1 item(s) ----
#    (0008, 1140)  Referenced Image Sequence  1 item(s) ----
#       (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.14519.5.2.1.7310.5101.221699974841901762919346790174
#       ---------
#    (0020, 000e) Series Instance UID                 UI: 1.3.6.1.4.1.14519.5.2.1.7310.5101.148630187288528488034448277765
#    ---------
# (0010, 0010) Patient's Name                      PN: 'ProstateX-0297'
# (0010, 0020) Patient ID                          LO: 'ProstateX-0297'
# (0010, 0030) Patient's Birth Date                DA: ''
# (0010, 0040) Patient's Sex                       CS: 'M'
# (0018, 1020) Software Versions                   LO: '4.2.0'
# (0020, 000d) Study Instance UID                  UI: 1.3.6.1.4.1.14519.5.2.1.7310.5101.132095852879986524815648892842
# (0020, 000e) Series Instance UID                 UI: 2.25.103825992908644972896560567316749597014
# (0020, 0010) Study ID                            SH: ''
# (0020, 0011) Series Number                       IS: '999'
# (0070, 0001)  Graphic Annotation Sequence  1 item(s) ----
#    (0070, 0002) Graphic Layer                       CS: 'MEASURE'
#    (0070, 0008)  Text Object Sequence  2 item(s) ----
#       (0070, 0003) Bounding Box Annotation Units       CS: 'PIXEL'
#       (0070, 0006) Unformatted Text Value              ST: 'Length : 11.3 mm'
#       (0070, 0010) Bounding Box Top Left Hand Corner   FL: [156.48338317871094, 210.3887481689453]
#       (0070, 0011) Bounding Box Bottom Right Hand Corn FL: [262.72637939453125, 228.3877410888672]
#       ---------
#       (0070, 0003) Bounding Box Annotation Units       CS: 'PIXEL'
#       (0070, 0006) Unformatted Text Value              ST: 'Length : 12.6 mm'
#       (0070, 0010) Bounding Box Top Left Hand Corner   FL: [149.45013427734375, 209.42967224121094]
#       (0070, 0011) Bounding Box Bottom Right Hand Corn FL: [255.69313049316406, 227.4286651611328]
#       ---------
#    (0070, 0009)  Graphic Object Sequence  2 item(s) ----
#       (0070, 0005) Graphic Annotation Units            CS: 'PIXEL'
#       (0070, 0020) Graphic Dimensions                  US: 2
#       (0070, 0021) Number of Graphic Points            US: 2
#       (0070, 0022) Graphic Data                        FL: [156.48338317871094, 203.79795837402344, 150.72889709472656, 222.9795379638672]
#       (0070, 0023) Graphic Type                        CS: 'POLYLINE'
#       (0070, 0024) Graphic Filled                      CS: 'N'
#       (0070, 0232)  Line Style Sequence  1 item(s) ----
#          (0070, 0251) Pattern On Color CIELab Value       US: [63658, 27358, 57178]
#          (0070, 0253) Line Thickness                      FL: 1.0
#          ---------
#       ---------
#       (0070, 0005) Graphic Annotation Units            CS: 'PIXEL'
#       (0070, 0020) Graphic Dimensions                  US: 2
#       (0070, 0021) Number of Graphic Points            US: 2
#       (0070, 0022) Graphic Data                        FL: [149.45013427734375, 201.87979125976562, 141.77749633789062, 222.9795379638672]
#       (0070, 0023) Graphic Type                        CS: 'POLYLINE'
#       (0070, 0024) Graphic Filled                      CS: 'N'
#       (0070, 0232)  Line Style Sequence  1 item(s) ----
#          (0070, 0251) Pattern On Color CIELab Value       US: [63658, 27358, 57178]
#          (0070, 0253) Line Thickness                      FL: 1.0
#          ---------
#       ---------
#    ---------
# (0070, 0060)  Graphic Layer Sequence  1 item(s) ----
#    (0070, 0002) Graphic Layer                       CS: 'MEASURE'
#    (0070, 0062) Graphic Layer Order                 IS: '0'
#    (0070, 0068) Graphic Layer Description           LO: 'Measurements'
#    (0070, 0401) Graphic Layer Recommended Display C US: [63658, 27358, 57178]
#    ---------
# (0070, 0080) Content Label                       CS: 'GSPS'
# (0070, 0081) Content Description                 LO: 'Description'
# (0070, 0082) Presentation Creation Date          DA: '20231102'
# (0070, 0083) Presentation Creation Time          TM: '195758.185'
# (0070, 0084) Content Creator's Name              PN: 'adamoshadjivasiliou'
# (7107, 0070) Private Creator                     LO: 'weasis/model/xml/2.5'
# (7107, 7001) Private tag data                    UN: Array of 584 elements, Dataset.file_meta -------------------------------
# (0002, 0000) File Meta Information Group Length  UL: 174
# (0002, 0001) File Meta Information Version       OB: b'\x00\x01'
# (0002, 0002) Media Storage SOP Class UID         UI: Grayscale Softcopy Presentation State Storage
# (0002, 0003) Media Storage SOP Instance UID      UI: 2.25.73108920926566637329862136853955258588
# (0002, 0010) Transfer Syntax UID                 UI: Implicit VR Little Endian
# (0002, 0012) Implementation Class UID            UI: 1.2.40.0.13.1.3
# (0002, 0013) Implementation Version Name         SH: 'dcm4che-5.30.0'
# -------------------------------------------------
# (0008, 0005) Specific Character Set              CS: 'ISO_IR 100'
# (0008, 0016) SOP Class UID                       UI: Grayscale Softcopy Presentation State Storage
# (0008, 0018) SOP Instance UID                    UI: 2.25.73108920926566637329862136853955258588
# (0008, 0020) Study Date                          DA: '20110302'
# (0008, 0023) Content Date                        DA: '20231102'
# (0008, 0030) Study Time                          TM: '082153.984000'
# (0008, 0033) Content Time                        TM: '195758.473'
# (0008, 0050) Accession Number                    SH: '7102759196100044'
# (0008, 0060) Modality                            CS: 'PR'
# (0008, 1010) Station Name                        SH: 'ahadjivasiliou.cs.ucl.ac.uk'
# (0008, 1030) Study Description                   LO: 'MR prostaat kanker detectie WDS_mc MCAPRODETW'
# (0008, 103e) Series Description                  LO: 'Weasis GSPS'
# (0008, 1115)  Referenced Series Sequence  1 item(s) ----
#    (0008, 1140)  Referenced Image Sequence  1 item(s) ----
#       (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.14519.5.2.1.7310.5101.612850553326072699431442521875
#       ---------
#    (0020, 000e) Series Instance UID                 UI: 1.3.6.1.4.1.14519.5.2.1.7310.5101.173634165163736512539537051866
#    ---------
# (0010, 0010) Patient's Name                      PN: 'ProstateX-0292'
# (0010, 0020) Patient ID                          LO: 'ProstateX-0292'
# (0010, 0030) Patient's Birth Date                DA: ''
# (0010, 0040) Patient's Sex                       CS: 'M'
# (0018, 1020) Software Versions                   LO: '4.2.0'
# (0020, 000d) Study Instance UID                  UI: 1.3.6.1.4.1.14519.5.2.1.7310.5101.153403907207453476614508163620
# (0020, 000e) Series Instance UID                 UI: 2.25.64137513530572733962644011783522107570
# (0020, 0010) Study ID                            SH: ''
# (0020, 0011) Series Number                       IS: '999'
# (0070, 0001)  Graphic Annotation Sequence  1 item(s) ----
#    (0070, 0002) Graphic Layer                       CS: 'MEASURE'
#    (0070, 0008)  Text Object Sequence  2 item(s) ----
#       (0070, 0003) Bounding Box Annotation Units       CS: 'PIXEL'
#       (0070, 0006) Unformatted Text Value              ST: 'Length : 18.2 mm'
#       (0070, 0010) Bounding Box Top Left Hand Corner   FL: [194.20716857910156, 221.5780029296875]
#       (0070, 0011) Bounding Box Bottom Right Hand Corn FL: [300.4501647949219, 239.57701110839844]
#       ---------
#       (0070, 0003) Bounding Box Annotation Units       CS: 'PIXEL'
#       (0070, 0006) Unformatted Text Value              ST: 'Length : 19.2 mm'
#       (0070, 0010) Bounding Box Top Left Hand Corner   FL: [184.61636352539062, 219.34014892578125]
#       (0070, 0011) Bounding Box Bottom Right Hand Corn FL: [290.859375, 237.3391571044922]
#       ---------
#    (0070, 0009)  Graphic Object Sequence  2 item(s) ----
#       (0070, 0005) Graphic Annotation Units            CS: 'PIXEL'
#       (0070, 0020) Graphic Dimensions                  US: 2
#       (0070, 0021) Number of Graphic Points            US: 2
#       (0070, 0022) Graphic Data                        FL: [194.20716857910156, 208.9130401611328, 185.8951416015625, 240.2429656982422]
#       (0070, 0023) Graphic Type                        CS: 'POLYLINE'
#       (0070, 0024) Graphic Filled                      CS: 'N'
#       (0070, 0232)  Line Style Sequence  1 item(s) ----
#          (0070, 0251) Pattern On Color CIELab Value       US: [63658, 27358, 57178]
#          (0070, 0253) Line Thickness                      FL: 1.0
#          ---------
#       ---------
#       (0070, 0005) Graphic Annotation Units            CS: 'PIXEL'
#       (0070, 0020) Graphic Dimensions                  US: 2
#       (0070, 0021) Number of Graphic Points            US: 2
#       (0070, 0022) Graphic Data                        FL: [184.61636352539062, 205.7161102294922, 176.94374084472656, 238.9641876220703]
#       (0070, 0023) Graphic Type                        CS: 'POLYLINE'
#       (0070, 0024) Graphic Filled                      CS: 'N'
#       (0070, 0232)  Line Style Sequence  1 item(s) ----
#          (0070, 0251) Pattern On Color CIELab Value       US: [63658, 27358, 57178]
#          (0070, 0253) Line Thickness                      FL: 1.0
#          ---------
#       ---------
#    ---------
# (0070, 0060)  Graphic Layer Sequence  1 item(s) ----
#    (0070, 0002) Graphic Layer                       CS: 'MEASURE'
#    (0070, 0062) Graphic Layer Order                 IS: '0'
#    (0070, 0068) Graphic Layer Description           LO: 'Measurements'
#    (0070, 0401) Graphic Layer Recommended Display C US: [63658, 27358, 57178]
#    ---------
# (0070, 0080) Content Label                       CS: 'GSPS'
# (0070, 0081) Content Description                 LO: 'Description'
# (0070, 0082) Presentation Creation Date          DA: '20231102'
# (0070, 0083) Presentation Creation Time          TM: '195758.473'
# (0070, 0084) Content Creator's Name              PN: 'adamoshadjivasiliou'
# (7107, 0070) Private Creator                     LO: 'weasis/model/xml/2.5'
# (7107, 7001) Private tag data                    UN: Array of 604 elements, Dataset.file_meta -------------------------------
# (0002, 0000) File Meta Information Group Length  UL: 174
# (0002, 0001) File Meta Information Version       OB: b'\x00\x01'
# (0002, 0002) Media Storage SOP Class UID         UI: Grayscale Softcopy Presentation State Storage
# (0002, 0003) Media Storage SOP Instance UID      UI: 2.25.132942094025121614862319350056917350160
# (0002, 0010) Transfer Syntax UID                 UI: Implicit VR Little Endian
# (0002, 0012) Implementation Class UID            UI: 1.2.40.0.13.1.3
# (0002, 0013) Implementation Version Name         SH: 'dcm4che-5.30.0'
# -------------------------------------------------
# (0008, 0005) Specific Character Set              CS: 'ISO_IR 100'
# (0008, 0016) SOP Class UID                       UI: Grayscale Softcopy Presentation State Storage
# (0008, 0018) SOP Instance UID                    UI: 2.25.132942094025121614862319350056917350160
# (0008, 0020) Study Date                          DA: '20110301'
# (0008, 0023) Content Date                        DA: '20231102'
# (0008, 0030) Study Time                          TM: '093442.875000'
# (0008, 0033) Content Time                        TM: '195758.558'
# ...
#    (0008, 1140)  Referenced Image Sequence  1 item(s) ----
#       (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.14519.5.2.1.7310.5101.283936273022471513390822151014
#       ---------
#    (0020, 000e) Series Instance UID                 UI: 1.3.6.1.4.1.14519.5.2.1.7310.5101.508492706541174730060641976638
#    ---------
# (0010, 0010) Patient's Name                      PN: 'ProstateX-0298'
# (0010, 0020) Patient ID                          LO: 'ProstateX-0298'
# (0010, 0030) Patient's Birth Date                DA: ''
# (0010, 0040) Patient's Sex                       CS: 'M'
# (0018, 1020) Software Versions                   LO: '4.2.0'
# (0020, 000d) Study Instance UID                  UI: 1.3.6.1.4.1.14519.5.2.1.7310.5101.296540990205552513385171769513
# (0020, 000e) Series Instance UID                 UI: 2.25.252039340018973437502430004903746042704
# (0020, 0010) Study ID                            SH: ''
# (0020, 0011) Series Number                       IS: '999'
# (0070, 0001)  Graphic Annotation Sequence  1 item(s) ----
#    (0070, 0002) Graphic Layer                       CS: 'MEASURE'
#    (0070, 0008)  Text Object Sequence  2 item(s) ----
#       (0070, 0003) Bounding Box Annotation Units       CS: 'PIXEL'
#       (0070, 0006) Unformatted Text Value              ST: 'Length : 21.8 mm'
#       (0070, 0010) Bounding Box Top Left Hand Corner   FL: [148.8107452392578, 202.07672119140625]
#       (0070, 0011) Bounding Box Bottom Right Hand Corn FL: [255.05374145507812, 220.0757293701172]
#       ---------
#       (0070, 0003) Bounding Box Annotation Units       CS: 'PIXEL'
#       (0070, 0006) Unformatted Text Value              ST: 'Length : 21.5 mm'
#       (0070, 0010) Bounding Box Top Left Hand Corner   FL: [140.49871826171875, 198.2404022216797]
#       (0070, 0011) Bounding Box Bottom Right Hand Corn FL: [246.74171447753906, 216.23941040039062]
#       ---------
#    (0070, 0009)  Graphic Object Sequence  2 item(s) ----
#       (0070, 0005) Graphic Annotation Units            CS: 'PIXEL'
#       (0070, 0020) Graphic Dimensions                  US: 2
#       (0070, 0021) Number of Graphic Points            US: 2
#       (0070, 0022) Graphic Data                        FL: [148.8107452392578, 188.4526824951172, 128.98977661132812, 221.7007598876953]
#       (0070, 0023) Graphic Type                        CS: 'POLYLINE'
#       (0070, 0024) Graphic Filled                      CS: 'N'
#       (0070, 0232)  Line Style Sequence  1 item(s) ----
#          (0070, 0251) Pattern On Color CIELab Value       US: [63658, 27358, 57178]
#          (0070, 0253) Line Thickness                      FL: 1.0
#          ---------
#       ---------
#       (0070, 0005) Graphic Annotation Units            CS: 'PIXEL'
#       (0070, 0020) Graphic Dimensions                  US: 2
#       (0070, 0021) Number of Graphic Points            US: 2
#       (0070, 0022) Graphic Data                        FL: [140.49871826171875, 185.25575256347656, 119.39897918701172, 217.22506713867188]
#       (0070, 0023) Graphic Type                        CS: 'POLYLINE'
#       (0070, 0024) Graphic Filled                      CS: 'N'
#       (0070, 0232)  Line Style Sequence  1 item(s) ----
#          (0070, 0251) Pattern On Color CIELab Value       US: [63658, 27358, 57178]
#          (0070, 0253) Line Thickness                      FL: 1.0
#          ---------
#       ---------
#    ---------
# (0070, 0060)  Graphic Layer Sequence  1 item(s) ----
#    (0070, 0002) Graphic Layer                       CS: 'MEASURE'
#    (0070, 0062) Graphic Layer Order                 IS: '0'
#    (0070, 0068) Graphic Layer Description           LO: 'Measurements'
#    (0070, 0401) Graphic Layer Recommended Display C US: [63658, 27358, 57178]
#    ---------
# (0070, 0080) Content Label                       CS: 'GSPS'
# (0070, 0081) Content Description                 LO: 'Description'
# (0070, 0082) Presentation Creation Date          DA: '20231102'
# (0070, 0083) Presentation Creation Time          TM: '195758.887'
# (0070, 0084) Content Creator's Name              PN: 'adamoshadjivasiliou'
# (7107, 0070) Private Creator                     LO: 'weasis/model/xml/2.5'
# (7107, 7001) Private tag data                    UN: Array of 606 elements, Dataset.file_meta -------------------------------
# (0002, 0000) File Meta Information Group Length  UL: 174
# (0002, 0001) File Meta Information Version       OB: b'\x00\x01'
# (0002, 0002) Media Storage SOP Class UID         UI: Grayscale Softcopy Presentation State Storage
# (0002, 0003) Media Storage SOP Instance UID      UI: 2.25.297305481267213426782091372585429732337
# (0002, 0010) Transfer Syntax UID                 UI: Implicit VR Little Endian
# (0002, 0012) Implementation Class UID            UI: 1.2.40.0.13.1.3
# (0002, 0013) Implementation Version Name         SH: 'dcm4che-5.30.0'
# -------------------------------------------------
# (0008, 0005) Specific Character Set              CS: 'ISO_IR 100'
# (0008, 0016) SOP Class UID                       UI: Grayscale Softcopy Presentation State Storage
# (0008, 0018) SOP Instance UID                    UI: 2.25.297305481267213426782091372585429732337
# (0008, 0020) Study Date                          DA: '20110227'
# (0008, 0023) Content Date                        DA: '20231102'
# (0008, 0030) Study Time                          TM: '140617.984000'
# (0008, 0033) Content Time                        TM: '195758.931'
# (0008, 0050) Accession Number                    SH: '9843519042021676'
# (0008, 0060) Modality                            CS: 'PR'
# (0008, 1010) Station Name                        SH: 'ahadjivasiliou.cs.ucl.ac.uk'
# (0008, 1030) Study Description                   LO: 'MR prostaat kanker detectie WDS_mc MCAPRODETW'
# (0008, 103e) Series Description                  LO: 'Weasis GSPS'
# (0008, 1115)  Referenced Series Sequence  1 item(s) ----
#    (0008, 1140)  Referenced Image Sequence  1 item(s) ----
#       (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.14519.5.2.1.7310.5101.338622092052607125939125080760
#       ---------
#    (0020, 000e) Series Instance UID                 UI: 1.3.6.1.4.1.14519.5.2.1.7310.5101.150847401080056742049775325218
#    ---------
# (0010, 0010) Patient's Name                      PN: 'ProstateX-0285'
# (0010, 0020) Patient ID                          LO: 'ProstateX-0285'
# (0010, 0030) Patient's Birth Date                DA: ''
# (0010, 0040) Patient's Sex                       CS: 'M'
# (0018, 1020) Software Versions                   LO: '4.2.0'
# (0020, 000d) Study Instance UID                  UI: 1.3.6.1.4.1.14519.5.2.1.7310.5101.272829128066367612875610998991
# (0020, 000e) Series Instance UID                 UI: 2.25.270795531655249774710144906104378259594
# (0020, 0010) Study ID                            SH: ''
# (0020, 0011) Series Number                       IS: '999'
# (0070, 0001)  Graphic Annotation Sequence  1 item(s) ----
#    (0070, 0002) Graphic Layer                       CS: 'MEASURE'
#    (0070, 0008)  Text Object Sequence  2 item(s) ----
#       (0070, 0003) Bounding Box Annotation Units       CS: 'PIXEL'
#       (0070, 0006) Unformatted Text Value              ST: 'Length : 15 mm'
#       (0070, 0010) Bounding Box Top Left Hand Corner   FL: [174.3861846923828, 209.42967224121094]
#       (0070, 0011) Bounding Box Bottom Right Hand Corn FL: [269.6291809082031, 227.4286651611328]
#       ---------
#       (0070, 0003) Bounding Box Annotation Units       CS: 'PIXEL'
#       (0070, 0006) Unformatted Text Value              ST: 'Length : 11.6 mm'
#       (0070, 0010) Bounding Box Top Left Hand Corner   FL: [160.95907592773438, 207.1918182373047]
#       (0070, 0011) Bounding Box Bottom Right Hand Corn FL: [267.20208740234375, 225.19081115722656]
#       ---------
#    (0070, 0009)  Graphic Object Sequence  2 item(s) ----
#       (0070, 0005) Graphic Annotation Units            CS: 'PIXEL'
#       (0070, 0020) Graphic Dimensions                  US: 2
#       (0070, 0021) Number of Graphic Points            US: 2
#       (0070, 0022) Graphic Data                        FL: [174.3861846923828, 200.6010284423828, 162.23785400390625, 224.25831604003906]
#       (0070, 0023) Graphic Type                        CS: 'POLYLINE'
#       (0070, 0024) Graphic Filled                      CS: 'N'
#       (0070, 0232)  Line Style Sequence  1 item(s) ----
#          (0070, 0251) Pattern On Color CIELab Value       US: [63658, 27358, 57178]
#          (0070, 0253) Line Thickness                      FL: 1.0
#          ---------
#       ---------
#       (0070, 0005) Graphic Annotation Units            CS: 'PIXEL'
#       (0070, 0020) Graphic Dimensions                  US: 2
#       (0070, 0021) Number of Graphic Points            US: 2
#       (0070, 0022) Graphic Data                        FL: [160.95907592773438, 200.6010284423828, 153.28643798828125, 219.78260803222656]
#       (0070, 0023) Graphic Type                        CS: 'POLYLINE'
#       (0070, 0024) Graphic Filled                      CS: 'N'
#       (0070, 0232)  Line Style Sequence  1 item(s) ----
#          (0070, 0251) Pattern On Color CIELab Value       US: [63658, 27358, 57178]
#          (0070, 0253) Line Thickness                      FL: 1.0
#          ---------
#       ---------
#    ---------
# (0070, 0060)  Graphic Layer Sequence  1 item(s) ----
#    (0070, 0002) Graphic Layer                       CS: 'MEASURE'
#    (0070, 0062) Graphic Layer Order                 IS: '0'
#    (0070, 0068) Graphic Layer Description           LO: 'Measurements'
#    (0070, 0401) Graphic Layer Recommended Display C US: [63658, 27358, 57178]
#    ---------
# (0070, 0080) Content Label                       CS: 'GSPS'
# (0070, 0081) Content Description                 LO: 'Description'
# (0070, 0082) Presentation Creation Date          DA: '20231102'
# (0070, 0083) Presentation Creation Time          TM: '195758.931'
# (0070, 0084) Content Creator's Name              PN: 'adamoshadjivasiliou'
# (7107, 0070) Private Creator                     LO: 'weasis/model/xml/2.5'
# (7107, 7001) Private tag data                    UN: Array of 594 elements, Dataset.file_meta -------------------------------
# (0002, 0000) File Meta Information Group Length  UL: 174
# (0002, 0001) File Meta Information Version       OB: b'\x00\x01'
# (0002, 0002) Media Storage SOP Class UID         UI: Grayscale Softcopy Presentation State Storage
# (0002, 0003) Media Storage SOP Instance UID      UI: 2.25.286785408642249457484397767355065363538
# (0002, 0010) Transfer Syntax UID                 UI: Implicit VR Little Endian
# (0002, 0012) Implementation Class UID            UI: 1.2.40.0.13.1.3
# (0002, 0013) Implementation Version Name         SH: 'dcm4che-5.30.0'
# -------------------------------------------------
# (0008, 0005) Specific Character Set              CS: 'ISO_IR 100'
# (0008, 0016) SOP Class UID                       UI: Grayscale Softcopy Presentation State Storage
# (0008, 0018) SOP Instance UID                    UI: 2.25.286785408642249457484397767355065363538
# (0008, 0020) Study Date                          DA: '20110305'
# (0008, 0023) Content Date                        DA: '20231102'
# (0008, 0030) Study Time                          TM: '095528.484000'
# (0008, 0033) Content Time                        TM: '195759.199'
# (0008, 0050) Accession Number                    SH: '1642497757025848'
# (0008, 0060) Modality                            CS: 'PR'
# (0008, 1010) Station Name                        SH: 'ahadjivasiliou.cs.ucl.ac.uk'
# (0008, 1030) Study Description                   LO: 'MR prostaat kanker detectie WDS_mc MCAPRODETW'
# (0008, 103e) Series Description                  LO: 'Weasis GSPS'
# (0008, 1115)  Referenced Series Sequence  1 item(s) ----
#    (0008, 1140)  Referenced Image Sequence  1 item(s) ----
#       (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.14519.5.2.1.7310.5101.255853666384147418692114666499
#       ---------
#    (0020, 000e) Series Instance UID                 UI: 1.3.6.1.4.1.14519.5.2.1.7310.5101.167234500578486519322386578938
#    ---------
# (0010, 0010) Patient's Name                      PN: 'ProstateX-0295'
# (0010, 0020) Patient ID                          LO: 'ProstateX-0295'
# (0010, 0030) Patient's Birth Date                DA: ''
# (0010, 0040) Patient's Sex                       CS: 'M'
# (0018, 1020) Software Versions                   LO: '4.2.0'
# (0020, 000d) Study Instance UID                  UI: 1.3.6.1.4.1.14519.5.2.1.7310.5101.227681521106946552522350815662
# (0020, 000e) Series Instance UID                 UI: 2.25.335299948024805890706744950565794627683
# (0020, 0010) Study ID                            SH: ''
# (0020, 0011) Series Number                       IS: '999'
# (0070, 0001)  Graphic Annotation Sequence  1 item(s) ----
#    (0070, 0002) Graphic Layer                       CS: 'MEASURE'
#    (0070, 0008)  Text Object Sequence  2 item(s) ----
#       (0070, 0003) Bounding Box Annotation Units       CS: 'PIXEL'
#       (0070, 0006) Unformatted Text Value              ST: 'Length : 11 mm'
#       (0070, 0010) Bounding Box Top Left Hand Corner   FL: [154.56521606445312, 204.63427734375]
#       (0070, 0011) Bounding Box Bottom Right Hand Corn FL: [249.80821228027344, 222.63327026367188]
#       ---------
#       (0070, 0003) Bounding Box Annotation Units       CS: 'PIXEL'
#       (0070, 0006) Unformatted Text Value              ST: 'Length : 12 mm'
#       (0070, 0010) Bounding Box Top Left Hand Corner   FL: [146.25320434570312, 202.07672119140625]
#       (0070, 0011) Bounding Box Bottom Right Hand Corn FL: [241.49620056152344, 220.0757293701172]
#       ---------
#    (0070, 0009)  Graphic Object Sequence  2 item(s) ----
#       (0070, 0005) Graphic Annotation Units            CS: 'PIXEL'
#       (0070, 0020) Graphic Dimensions                  US: 2
#       (0070, 0021) Number of Graphic Points            US: 2
#       (0070, 0022) Graphic Data                        FL: [154.56521606445312, 201.2404022216797, 139.8593292236328, 214.02813720703125]
#       (0070, 0023) Graphic Type                        CS: 'POLYLINE'
#       (0070, 0024) Graphic Filled                      CS: 'N'
#       (0070, 0232)  Line Style Sequence  1 item(s) ----
#          (0070, 0251) Pattern On Color CIELab Value       US: [63658, 27358, 57178]
#          (0070, 0253) Line Thickness                      FL: 1.0
#          ---------
#       ---------
#       (0070, 0005) Graphic Annotation Units            CS: 'PIXEL'
#       (0070, 0020) Graphic Dimensions                  US: 2
#       (0070, 0021) Number of Graphic Points            US: 2
#       (0070, 0022) Graphic Data                        FL: [146.25320434570312, 198.04347229003906, 130.26853942871094, 212.10997009277344]
#       (0070, 0023) Graphic Type                        CS: 'POLYLINE'
#       (0070, 0024) Graphic Filled                      CS: 'N'
#       (0070, 0232)  Line Style Sequence  1 item(s) ----
#          (0070, 0251) Pattern On Color CIELab Value       US: [63658, 27358, 57178]
#          (0070, 0253) Line Thickness                      FL: 1.0
#          ---------
#       ---------
#    ---------
# (0070, 0060)  Graphic Layer Sequence  1 item(s) ----
#    (0070, 0002) Graphic Layer                       CS: 'MEASURE'
#    (0070, 0062) Graphic Layer Order                 IS: '0'
#    (0070, 0068) Graphic Layer Description           LO: 'Measurements'
#    (0070, 0401) Graphic Layer Recommended Display C US: [63658, 27358, 57178]
#    ---------
# (0070, 0080) Content Label                       CS: 'GSPS'
# (0070, 0081) Content Description                 LO: 'Description'
# (0070, 0082) Presentation Creation Date          DA: '20231102'
# (0070, 0083) Presentation Creation Time          TM: '195759.199'
# (0070, 0084) Content Creator's Name              PN: 'adamoshadjivasiliou'
# (7107, 0070) Private Creator                     LO: 'weasis/model/xml/2.5'
# (7107, 7001) Private tag data                    UN: Array of 612 elements]

# %%
print(f"Found {len(gsps_objects)} annotations")
# Out:
# Found 15 annotations

# %%
def get_mul_length(mask_lines, mode="both"):
    if mode == "right":
        mask_lines = [mask_lines[0]]
    elif mode == "left":
        mask_lines = [mask_lines[1]]

    length = 0
    for m_line in mask_lines:
        x1, y1 = m_line[0]
        x2, y2 = m_line[1]
        length += np.sqrt((x2 - x1) ** 2 + (y2 - y1) ** 2)
    if mode == "both":
        length /= 2
    return length

# %%
def save_image_with_annotations(gsps_dataset, image_dataset, plot=False):
    if plot:
        fig, axes = plt.subplots(1, 3, figsize=(12, 4))  # 1 row, 3 columns

        # Plot the image
        axes[0].imshow(image_dataset.pixel_array, cmap=plt.cm.bone)

    # ADDED: list of lines in mask
    mask_lines = []

    # Extract the Graphic Annotation Sequence from the GSPS object
    graphic_annotation_sequence = gsps_dataset.get((0x0070, 0x0001), [])

    for annotation in graphic_annotation_sequence:
        # Process Graphic Object Sequence if present
        for graphic_object in annotation.get((0x0070, 0x0009), []):
            graphic_data = graphic_object.GraphicData
            # Assuming POLYLINE type for simplicity; you will need to adapt this based on the actual GraphicType
            if graphic_object.GraphicType == "POLYLINE":
                # POLYLINE should have pairs of points (x, y), so we reshape the flat list into a list of tuples
                polyline = list(zip(graphic_data[::2], graphic_data[1::2]))
                # print("polyline", polyline)
                # We then split these tuples into two lists for x and y coordinates
                x, y = zip(*polyline)

                # ADDED: append to mask_lines
                mask_lines.append(polyline)

                if plot:
                    axes[0].plot(x, y, linestyle="-", linewidth=2, color="red")

    patient_id = gsps_dataset.PatientName

    # ADDED: save image files
    image_file = os.path.join(
        numpy_path, f"images_best_slice/slice_{patient_id}.npy"
    )
    np.save(image_file, image_dataset.pixel_array)

    # ADDED: save mask files
    both_mask = get_image_mask_binary(
        image_dataset.pixel_array, mask_lines, mode="both"
    )
    right_mask = get_image_mask_binary(
        image_dataset.pixel_array, mask_lines, mode="right"
    )

    both_mask_file = os.path.join(
        numpy_path, f"masks_both/mask_both_{patient_id}_both.npy"
    )
    right_mask_file = os.path.join(
        numpy_path, f"masks_right/mask_right_{patient_id}.npy"
    )
    np.save(both_mask_file, both_mask)
    np.save(right_mask_file, right_mask)
    print("Saved image and mask files.\n")

    if plot:
        axes[1].imshow(both_mask, cmap=plt.cm.bone)
        axes[2].imshow(right_mask, cmap=plt.cm.bone)
        plt.show()

    num_slices = None
    best_slice = int(image_dataset.InstanceNumber)
    mul_avg = get_mul_length(mask_lines, mode="both")
    mul_right = get_mul_length(mask_lines, mode="right")

    row = patient_id, num_slices, best_slice, mul_avg, mul_right
    return row


def get_image_mask_binary(image_array, mask_lines, mode="both"):
    mask = np.zeros(image_array.shape, dtype="uint8")

    if mode == "right":
        mask_lines = [mask_lines[0]]
    elif mode == "left":
        mask_lines = [mask_lines[1]]

    for m_line in mask_lines:
        m_line_points = list(reversed(m_line[0])) + list(reversed(m_line[1]))
        m_line_points = [int(x) for x in m_line_points]
        rr, cc = line(*m_line_points)
        mask[rr, cc] = 1

    return mask

# %%
def find_referenced_image(gsps_dataset, dicom_index):
    referenced_sop_instance_uid = (
        gsps_ds.ReferencedSeriesSequence[0]
        .ReferencedImageSequence[0]
        .ReferencedSOPInstanceUID
    )
    if referenced_sop_instance_uid in dicom_index:
        # print("Found referenced image")
        # print("- SOP Instance UID:", referenced_sop_instance_uid)
        image_path = os.path.join(dicom_path, dicom_index[referenced_sop_instance_uid])
        return pydicom.dcmread(image_path, force=True)
    # print("Could not find referenced image")
    return None

rows = []

# Process GSPS objects
for gsps_ds in gsps_objects:
    # Find the referenced image dataset
    # print("Searching for referenced image of GSPS object...")
    image_ds = find_referenced_image(gsps_ds, dicom_index)
    # print(image_ds)

    try:
        if image_ds:
            # Save the image with annotations
            row = save_image_with_annotations(gsps_ds, image_ds, plot=False)
            rows.append(row)
            # Assuming we only want to plot the first matching image and annotation set
    except Exception as e:
        print(e)
# Out:
# Saved image and mask files.
#
# Saved image and mask files.
#
# Saved image and mask files.
#
# Saved image and mask files.
#
# Saved image and mask files.
#
# Saved image and mask files.
#
# Saved image and mask files.
#
# Saved image and mask files.
#
# Saved image and mask files.
#
# Saved image and mask files.
#
# Saved image and mask files.
#
# Saved image and mask files.
#
# Saved image and mask files.
#
# Saved image and mask files.
#
# Saved image and mask files.

# %%
csv_path = "../data/info.csv"

import csv
with open(csv_path, "a") as f:
    writer = csv.writer(f)
    writer.writerows(rows)
